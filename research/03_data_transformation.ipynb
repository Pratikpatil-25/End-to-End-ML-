# %%
import os

# %%
# %pwd
# Out:
# 'p:\\OM\\Projects\\End-to-End-ML-\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'p:\\OM\\Projects\\End-to-End-ML-'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen = True)
class DataTransformationConfig:
    root_dir : Path
    data_path : Path

# %%
from src.wine.constants import *
from src.wine.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_file_path = CONFIG_FILE_PATH,
        params_file_path = PARAMS_FILE_PATH,
        schema_file_path = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_file_path)
        self.params = read_yaml(params_file_path)
        self.schema = read_yaml(schema_file_path)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
        )

        return data_transformation_config

# %%
import os
from src.wine.logging import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    # perform EDA
    # perform data transformation techniques such as scaling, standardization, PCA, feature scaling, etc.
    # perform train_test_split

    # here we are just adding train_test_spliting because this data is already cleaned up


    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)

        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"),index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"),index = False)

        logger.info("Splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [ 2026-06-21 16:03:30,112 : INFO : common : yaml file: config\config.yaml loaded successfully ]
# [ 2026-06-21 16:03:30,114 : INFO : common : yaml file: params.yaml loaded successfully ]
# [ 2026-06-21 16:03:30,120 : INFO : common : yaml file: schema.yaml loaded successfully ]
# [ 2026-06-21 16:03:30,123 : INFO : common : created directory at: artifacts ]
# [ 2026-06-21 16:03:30,126 : INFO : common : created directory at: artifacts/data_transformation ]
# [ 2026-06-21 16:03:30,174 : INFO : 1193952610 : Splited data into training and test sets ]
# [ 2026-06-21 16:03:30,176 : INFO : 1193952610 : (857, 13) ]
# [ 2026-06-21 16:03:30,177 : INFO : 1193952610 : (286, 13) ]
# (857, 13)
# (286, 13)
